# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('vizita-si-scraper.csv')
df = pd.DataFrame(data)
df
# Out:
#                                             title  \
# 0                            Tresenje in napetost
# 1              Napad tresavice in razbijanje srca
# 2                          Aksilarna hiperhidroza
# 3                                 Srbečica prstov
# 4                                   Luščenje kože
# 5                              Bolečina v stopalu
# 6                                Bolečine v križu
# 7                               Težave z erekcijo
# 8                   Posttravmatska stresna motnja
# 9   Izliv semenske tekočine z drobnimi kristalčki
# 10                                 Sključena drža
# 11                              Odstop steklovine
# 12           Sinova nejasna zdravstvena situacija
# 13                                Težave z nohtom
# 14                               Udarec v mezinec
# 15                 Sledovi krvi ob čiščenju ušesa
# 16                           Izpuščaji pod očesom
# 17                                Vnetje obnohtja
# ...
