# %% [markdown]
# ### PREVIEW

# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('vizita-si-scraper.csv', sep=';')
df = pd.DataFrame(data)
df
# Out:
#                                   title  \
# 0                  Tresenje in napetost
# 1    Napad tresavice in razbijanje srca
# 2                Aksilarna hiperhidroza
# 3                       Srbečica prstov
# 4                         Luščenje kože
# ..                                  ...
# 195                       Zastanek seča
# 196                         Mehur po KT
# 197                          Brazgotina
# 198                        Rak prostate
# 199              Po operaciji hidrokele
#
#                                               question  \
# 0    Pozdravljeni, pred leti ste neki punci svetova...
# 1    Pozdravljeni. Imam napade tresavice in razbija...
# 2    Pozdravljeni! Že dolga leta se bojujem z aksil...
# 3    Pozdravljeni, pred nekaj meseci sem začela opa...
# 4    Na nekaterih mestih na obrazu, se mi lušči kož...
# ..                                                 ...
# 195  Pozdravljeni! Star sem 38 let in imam postavlj...
# ...

# %%
# Print titles of empty rows
empty = df[(df['question'].isnull()) & (df['answer'].isnull())]
print(empty['title'])
# Out:
# 24                          Težave z vraščenimi dlakami
# 25               Težave s hrbtenico in bolečine v vratu
# 26                              Nateg dimeljske prepone
# 27                    Kronične bolečine v predelu križa
# 28     Hude bolečine v ledvenem delu, zadnjici in nogah
# 29                                       Vodni mehurčki
# 30                                     Težave s spanjem
# 31                          Pekoča bolečina in zbadanje
# 32                                     Zamašene lojnice
# 33                                       Težave z zobmi
# 34                             Zlom lateralnega maleola
# 35     Od okolice prejemam očitke, da sem nezdravo suha
# 36    Je kombinacija zdravil, ki so mi jih predpisal...
# 37    Več kot deset let se borim s stisko in občutki...
# 38                               Rdeči madeži na penisu
# 39                             Težave z uhajanjem urina
# 40                                    Težave z erekcijo
# ...
