# %% [markdown]
# ### PREVIEW

# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('vizita-si-scraper.csv', sep=';')
df = pd.DataFrame(data)
df
# Out:
#                                        title  \
# 0                       Tresenje in napetost
# 1         Napad tresavice in razbijanje srca
# 2                     Aksilarna hiperhidroza
# 3                            Srbečica prstov
# 4                              Luščenje kože
# ...                                      ...
# 29087                       Zlom nadlahtnice
# 29088                       Zatrdlina v modu
# 29089                             Anestezija
# 29090                       Široko povijanje
# 29091  Vizita.si - nova podoba, novi začetki
#
#                                                 question  \
# 0      Pozdravljeni, pred leti ste neki punci svetova...
# 1      Pozdravljeni. Imam napade tresavice in razbija...
# 2      Pozdravljeni! Že dolga leta se bojujem z aksil...
# 3      Pozdravljeni, pred nekaj meseci sem začela opa...
# 4      Na nekaterih mestih na obrazu, se mi lušči kož...
# ...                                                  ...
# 29087  Star sem petdeset let. Pred dvema letoma sem i...
# 29088  Nekaj časa si tipam zatrdlino v predelu desneg...
# 29089  Kaj mora bolnik povedati anesteziologu o sebi ...
# 29090    Do kdaj je potrebno široko povijanje dojenčkov?
# 29091                                                NaN
#
#                                                   answer
# 0      ob redni kontroli srčnega utripa in pribeležen...
# 1      Spoštovani!\n\nPredlagam, da poiščete pomoč s ...
# 2      Spoštovana,\n\npostopki, ki jih omenjate, so z...
# 3      Spoštovani,\n\nkot razumem, gre srbečo spremem...
# 4      Spoštovani,\n\nvzrokov za luščenje kože je kar...
# ...                                                  ...
# 29087  Kovinskih inplantatov (slovensko pravimo temu ...
# 29088  Vsaka zatrdlina v modih je lahko nevarna, čepr...
# 29089  Pred vsakim operativnim posegom anesteziolog p...
# 29090  Paviloma naj bi bili dojenčki široko poviti do...
# 29091                                                NaN
#
# [29092 rows x 3 columns]

# %%
# Print titles of empty rows
empty = df[(df['question'].isnull()) & (df['answer'].isnull())]
empty
# Out:
#                                                   title question answer
# 24                          Težave z vraščenimi dlakami      NaN    NaN
# 25               Težave s hrbtenico in bolečine v vratu      NaN    NaN
# 26                              Nateg dimeljske prepone      NaN    NaN
# 27                    Kronične bolečine v predelu križa      NaN    NaN
# 28     Hude bolečine v ledvenem delu, zadnjici in nogah      NaN    NaN
# ...                                                 ...      ...    ...
# 26828                                            Starsi      NaN    NaN
# 27717                  Bolečina v spodnjem delu trebuha      NaN    NaN
# 28182                                 Težave z erekcijo      NaN    NaN
# 28922                                  Alopecija areata      NaN    NaN
# 29091             Vizita.si - nova podoba, novi začetki      NaN    NaN
#
# [74 rows x 3 columns]
